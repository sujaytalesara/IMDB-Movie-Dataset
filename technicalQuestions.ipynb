# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movieFrame = pd.read_csv('Desktop\movies_data.csv')

# %%
movieFrame.head()
# Out:
#    MovieID                     title  year  length  budget  rating  votes  \
# 0        1                         $  1971     121     NaN     6.4    348
# 1        2         $1000 a Touchdown  1939      71     NaN     6.0     20
# 2        3    $21 a Day Once a Month  1941       7     NaN     8.2      5
# 3        4                   $40,000  1996      70     NaN     8.2      6
# 4        5  $50,000 Climax Show, The  1975      71     NaN     3.4     17
#
#      r1    r2   r3  ...      r9   r10  mpaa  Action  Animation  Comedy  Drama  \
# 0   4.5   4.5  4.5  ...     4.5   4.5   NaN       0          0       1      1
# 1   0.0  14.5  4.5  ...     4.5  14.5   NaN       0          0       1      0
# 2   0.0   0.0  0.0  ...    24.5  24.5   NaN       0          1       0      0
# 3  14.5   0.0  0.0  ...    34.5  45.5   NaN       0          0       1      0
# 4  24.5   4.5  0.0  ...     0.0  24.5   NaN       0          0       0      0
#
#   Documentary  Romance  Short
# ...

# %%
movieFrame['rating'] = movieFrame['rating'].round()
movieFrame.head()
# Out:
#    MovieID                     title  year  length  budget  rating  votes  \
# 0        1                         $  1971     121     NaN     6.0    348
# 1        2         $1000 a Touchdown  1939      71     NaN     6.0     20
# 2        3    $21 a Day Once a Month  1941       7     NaN     8.0      5
# 3        4                   $40,000  1996      70     NaN     8.0      6
# 4        5  $50,000 Climax Show, The  1975      71     NaN     3.0     17
#
#      r1    r2   r3  ...      r9   r10  mpaa  Action  Animation  Comedy  Drama  \
# 0   4.5   4.5  4.5  ...     4.5   4.5   NaN       0          0       1      1
# 1   0.0  14.5  4.5  ...     4.5  14.5   NaN       0          0       1      0
# 2   0.0   0.0  0.0  ...    24.5  24.5   NaN       0          1       0      0
# 3  14.5   0.0  0.0  ...    34.5  45.5   NaN       0          0       1      0
# 4  24.5   4.5  0.0  ...     0.0  24.5   NaN       0          0       0      0
#
#   Documentary  Romance  Short
# ...

# %%
# Question 1
ratingFrequency = movieFrame['rating'].value_counts()
ratingFrequency

#Answer - 
# 6.0     17233
# 7.0     12506
# 5.0      9509
# Out:
# 6.0     17233
# 7.0     12506
# 5.0      9509
# 8.0      6993
# 4.0      6309
# 3.0      2685
# 9.0      1689
# 2.0      1298
# 10.0      294
# 1.0       272
# Name: rating, dtype: int64

# %%
# Question 2 :
mpaaFrequency = movieFrame['mpaa'].value_counts()
mpaaFrequency

# R rated movies more.
# Out:
# R        3377
# PG-13    1003
# PG        528
# NC-17      16
# Name: mpaa, dtype: int64

# %%
# Question 3 :
Comedytotal = movieFrame['Comedy'].sum()
Actiontotal = movieFrame['Action'].sum()
Dramatotal = movieFrame['Drama'].sum()

print(Comedytotal)
print(Actiontotal)
print(Dramatotal)

# Drama movies more.
# Out:
# 17271
# 4688
# 21811

# %%
# Question 4 :

subsetFrame = movieFrame.loc[(movieFrame.Action + movieFrame.Comedy == 2) & (movieFrame.Drama + movieFrame.Animation + movieFrame.Short + movieFrame.Documentary + movieFrame.Romance == 0),['title']].count()
print('Total Movies ',subsetFrame)
# Out:
# Total Movies  title    533
# dtype: int64

# %%
# Question 5 :


print(movieFrame['rating'].describe())
print('Median -- ',movieFrame['rating'].median())
# Out:
# count    58788.000000
# mean         5.931976
# std          1.579101
# min          1.000000
# 25%          5.000000
# 50%          6.000000
# 75%          7.000000
# max         10.000000
# Name: rating, dtype: float64
# Median --  6.0

# %%
# Question 6 :

print('Rating vs Votes',movieFrame.rating.corr(movieFrame.votes))
print('Rating vs Length',movieFrame.rating.corr(movieFrame.length))
print('Rating vs Year',movieFrame.rating.corr(movieFrame.year))
# Out:
# Rating vs Votes 0.10131129802337543
# Rating vs Length -0.030017985145439994
# Rating vs Year -0.0682678828022892

# %%
# Question 7 : 

sns.regplot(data=movieFrame, x="rating", y="length", fit_reg=False, marker="+", color="skyblue")
p1=sns.regplot(data=movieFrame, x="rating", y="length", fit_reg=False, marker="o", color="skyblue", scatter_kws={'s':400})

# add annotations one by one with a loop
for line in range(0,df.shape[0]):
     p1.text(movieFrame.rating[line]+0.2, movieFrame.length[line], movieFrame.MovieID[line], horizontalalignment='left', size='small', color='black')
